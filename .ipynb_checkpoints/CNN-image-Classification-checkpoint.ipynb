# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.keras.datasets import cifar10

# %% [markdown]
# #### _Load the data and split into Train and Test sets_

# %%
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

# %%
#Inspect the data
print(f"X_train shape:{X_train.shape}")
print(f"Y_train shape:{Y_train.shape}")
print(f"X_test shape:{X_test.shape}")
print(f"Y_test shape:{Y_test.shape}")
print(f"Number of training examples/images:{X_train.shape[0]}")
print(f"Number of testing examples/images:{X_test.shape[0]}")
# Out:
# X_train shape:(50000, 32, 32, 3)
# Y_train shape:(50000, 1)
# X_test shape:(10000, 32, 32, 3)
# Y_test shape:(10000, 1)
# Number of training examples/images:50000
# Number of testing examples/images:10000

# %% [markdown]
# #### _Single image visualisation_

# %%
# Visualize the images in the training dataset
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
index = 100
plt.imshow(X_train[index])
plt.show()
print(f"Label:{class_names[Y_train[index][0]]}")
# Out:
# Label:ship

# %% [markdown]
# #### _Multiple image visualisation_

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(30):
    plt.subplot(5,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(visible=False)
    plt.imshow(X_train[i])
    plt.xlabel(class_names[Y_train[i][0]])
plt.show()

# %% [markdown]
# ### _Data Preprocessing_

# %%
# Normalize the images
X_train = X_train/255.0
X_test = X_test/255.0

#Convert labels to one hot encoded vectors
Y_train = tf.keras.utils.to_categorical(Y_train,num_classes=10)
Y_test = tf.keras.utils.to_categorical(Y_test,num_classes=10)

# %% [markdown]
# ### _Binary Classification Model with Sequential API_

# %%
# Convert the labels to a binary classification problem (Airplane vs Not Airplane)
Y_train_binary = np.where(Y_train[:,0] == 1,1,0) # class 0 for Airplane
Y_test_binary = np.where(Y_test[:,0] == 1,1,0)

# Build the Sequential model
binary_model = tf.keras.Sequential([
    tfl.Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(32,32,3)),
    tfl.MaxPooling2D(pool_size=(2,2)), #strides=(1,1), #padding='valid' Why are we not using these args?? 
    tfl.Conv2D(64, kernel_size=(3,3), activation='relu'),
    tfl.MaxPooling2D(pool_size=(2,2)),
    tfl.Conv2D(128, kernel_size=(3,3), activation='relu'),
    tfl.MaxPooling2D(pool_size=(2,2)),
    tfl.Flatten(),
    tfl.Dense(128, activation='relu'), 
    tfl.Dropout(0.5),
    tfl.Dense(1, activation='sigmoid')
])

# %%
binary_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# binary_model.summary()
binary_history = binary_model.fit(X_train, Y_train_binary, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 2024-08-01 22:56:30.377566: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 620/625 [============================>.] - ETA: 0s - loss: 0.0813 - accuracy: 0.9697
# 2024-08-01 22:56:36.527731: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 625/625 [==============================] - 7s 11ms/step - loss: 0.0817 - accuracy: 0.9694 - val_loss: 0.1740 - val_accuracy: 0.9480
# Epoch 2/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0699 - accuracy: 0.9739 - val_loss: 0.1944 - val_accuracy: 0.9456
# Epoch 3/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0630 - accuracy: 0.9772 - val_loss: 0.1900 - val_accuracy: 0.9368
# Epoch 4/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0579 - accuracy: 0.9793 - val_loss: 0.1847 - val_accuracy: 0.9442
# Epoch 5/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0536 - accuracy: 0.9804 - val_loss: 0.2004 - val_accuracy: 0.9425
# Epoch 6/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0431 - accuracy: 0.9842 - val_loss: 0.2388 - val_accuracy: 0.9456
# Epoch 7/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0390 - accuracy: 0.9859 - val_loss: 0.2683 - val_accuracy: 0.9449
# Epoch 8/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0359 - accuracy: 0.9872 - val_loss: 0.2367 - val_accuracy: 0.9456
# Epoch 9/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0382 - accuracy: 0.9859 - val_loss: 0.2544 - val_accuracy: 0.9437
# Epoch 10/10
# 625/625 [==============================] - 6s 10ms/step - loss: 0.0329 - accuracy: 0.9882 - val_loss: 0.2644 - val_accuracy: 0.9456

# %% [markdown]
# ### _Multiclass Classification Model with Functional API_

# %%
# Build the model
input_img = tf.keras.Input(shape=(32,32,3))

# Convolutional layers with ReLu activation and MaxPooling
Z1 = tfl.Conv2D(filters=32, kernel_size=(3,3))(input_img)
A1 = tfl.ReLU()(Z1)
P1 = tfl.MaxPooling2D(pool_size=(2,2))(A1)
Z2 = tfl.Conv2D(64, (3,3))(P1)
A2 = tfl.ReLU()(Z2)
P2 = tfl.MaxPooling2D((2,2))(A2)
Z3 = tfl.Conv2D(128, (3,3))(P2)
A3 = tfl.ReLU()(Z3)
P3 = tfl.MaxPooling2D((2,2))(A3)

# Flatten and Dense layer
F = tfl.Flatten()(P3)
FC1 = tfl.Dense(units=128, activation='relu')(F)
D = tfl.Dropout(0.5)(FC1)

# Output layer
output_layer = tfl.Dense(units=10, activation='softmax')(D)

functional_model = tf.keras.Model(inputs=input_img, outputs=output_layer)

# %%
functional_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# functional_model.summary()
functional_history = functional_model.fit(X_train, Y_train, epochs=30, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/30
#   1/625 [..............................] - ETA: 3:04 - loss: 2.3155 - accuracy: 0.1562
# 2024-08-02 01:42:44.692097: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 623/625 [============================>.] - ETA: 0s - loss: 1.7788 - accuracy: 0.3323
# 2024-08-02 01:42:52.570343: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 625/625 [==============================] - 9s 14ms/step - loss: 1.7783 - accuracy: 0.3325 - val_loss: 1.4579 - val_accuracy: 0.4740
# Epoch 2/30
# 625/625 [==============================] - 9s 14ms/step - loss: 1.4201 - accuracy: 0.4869 - val_loss: 1.2529 - val_accuracy: 0.5516
# Epoch 3/30
# 625/625 [==============================] - 9s 14ms/step - loss: 1.2806 - accuracy: 0.5450 - val_loss: 1.1618 - val_accuracy: 0.5884
# Epoch 4/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.1848 - accuracy: 0.5867 - val_loss: 1.1192 - val_accuracy: 0.6080
# Epoch 5/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.1169 - accuracy: 0.6118 - val_loss: 1.0601 - val_accuracy: 0.6320
# Epoch 6/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.0705 - accuracy: 0.6284 - val_loss: 1.0093 - val_accuracy: 0.6469
# Epoch 7/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.0338 - accuracy: 0.6459 - val_loss: 1.0520 - val_accuracy: 0.6383
# Epoch 8/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.0137 - accuracy: 0.6529 - val_loss: 1.0100 - val_accuracy: 0.6530
# Epoch 9/30
# 625/625 [==============================] - 8s 13ms/step - loss: 0.9848 - accuracy: 0.6638 - val_loss: 1.0108 - val_accuracy: 0.6578
# Epoch 10/30
# 625/625 [==============================] - 8s 13ms/step - loss: 0.9788 - accuracy: 0.6704 - val_loss: 0.9839 - val_accuracy: 0.6646
# Epoch 11/30
# 625/625 [==============================] - 8s 13ms/step - loss: 0.9691 - accuracy: 0.6743 - val_loss: 0.9463 - val_accuracy: 0.6817
# Epoch 12/30
# 625/625 [==============================] - 8s 14ms/step - loss: 0.9549 - accuracy: 0.6810 - val_loss: 0.9534 - val_accuracy: 0.6808
# Epoch 13/30
# 625/625 [==============================] - 8s 13ms/step - loss: 0.9535 - accuracy: 0.6833 - val_loss: 1.0353 - val_accuracy: 0.6537
# Epoch 14/30
# 625/625 [==============================] - 9s 14ms/step - loss: 0.9571 - accuracy: 0.6822 - val_loss: 1.0026 - val_accuracy: 0.6746
# Epoch 15/30
# 625/625 [==============================] - 8s 13ms/step - loss: 0.9449 - accuracy: 0.6917 - val_loss: 0.9619 - val_accuracy: 0.6766
# Epoch 16/30
# 625/625 [==============================] - 9s 14ms/step - loss: 0.9526 - accuracy: 0.6908 - val_loss: 1.0143 - val_accuracy: 0.6663
# Epoch 17/30
# 625/625 [==============================] - 8s 13ms/step - loss: 0.9621 - accuracy: 0.6910 - val_loss: 1.0644 - val_accuracy: 0.6701
# Epoch 18/30
# 625/625 [==============================] - 8s 13ms/step - loss: 0.9826 - accuracy: 0.6910 - val_loss: 1.0048 - val_accuracy: 0.6871
# Epoch 19/30
# 625/625 [==============================] - 8s 13ms/step - loss: 0.9777 - accuracy: 0.6945 - val_loss: 1.1286 - val_accuracy: 0.6568
# Epoch 20/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.0113 - accuracy: 0.6913 - val_loss: 1.0626 - val_accuracy: 0.6837
# Epoch 21/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.0012 - accuracy: 0.7002 - val_loss: 1.1120 - val_accuracy: 0.6798
# Epoch 22/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.0418 - accuracy: 0.6935 - val_loss: 1.0698 - val_accuracy: 0.6895
# Epoch 23/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.0853 - accuracy: 0.6893 - val_loss: 1.0365 - val_accuracy: 0.6955
# Epoch 24/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.1111 - accuracy: 0.6927 - val_loss: 1.1729 - val_accuracy: 0.6822
# Epoch 25/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.1487 - accuracy: 0.6907 - val_loss: 1.1143 - val_accuracy: 0.7010
# Epoch 26/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.1658 - accuracy: 0.6945 - val_loss: 1.2270 - val_accuracy: 0.6858
# Epoch 27/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.2192 - accuracy: 0.6944 - val_loss: 1.2528 - val_accuracy: 0.6892
# Epoch 28/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.2438 - accuracy: 0.6960 - val_loss: 1.2456 - val_accuracy: 0.6906
# Epoch 29/30
# 625/625 [==============================] - 8s 13ms/step - loss: 1.3132 - accuracy: 0.6935 - val_loss: 1.6667 - val_accuracy: 0.6453
# Epoch 30/30
# 625/625 [==============================] - 8s 14ms/step - loss: 1.4342 - accuracy: 0.6880 - val_loss: 1.5332 - val_accuracy: 0.6740

# %% [markdown]
# ### _Model evaluation_

# %%
# Evaluate the binary classification model
binary_test_loss, binary_test_acc = binary_model.evaluate(X_test,Y_test_binary)
print(f"Binary classification test loss: {binary_test_loss}")
print(f"Binary classification test accuracy: {binary_test_acc}")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2654 - accuracy: 0.9459
# Binary classification test loss: 0.2654421031475067
# Binary classification test accuracy: 0.945900022983551

# %%
# Evaluate the multiclass classification model
multiclass_test_loss, multiclass_test_acc = functional_model.evaluate(X_test, Y_test)
print(f"Multiclass classification test loss: {multiclass_test_loss}")
print(f"Multiclass classification test accuracy: {multiclass_test_acc}")
# Out:
# 313/313 [==============================] - 2s 8ms/step - loss: 1.5144 - accuracy: 0.6749
# Multiclass classification test loss: 1.514438271522522
# Multiclass classification test accuracy: 0.6748999953269958

# %% [markdown]
# ### _Plot accuracy_

# %%
# Plot training and validation accuracy
# Binary class model
plt.plot(binary_history.history["accuracy"])
plt.plot(binary_history.history["val_accuracy"])
plt.title("Binary model accuracy")
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.show()

# Multiclass model
plt.plot(functional_history.history['accuracy'])
plt.plot(functional_history.history['val_accuracy'])
plt.title('Multiclass model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='lower right')
plt.show()

# %% [markdown]
# ### _Save and Load_

# %%
functional_model.save('cifar10-functional-model.h5')
# Out:
# /Users/subhamgogoi/tensorflow-test/env/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
